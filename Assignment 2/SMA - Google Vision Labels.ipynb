# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "C:/Users/Owner/Downloads/My First Project-b9372fa08687.json"

# %%
# !pip install --upgrade google-cloud-vision
# Out:
# Collecting google-cloud-vision
#   Downloading https://files.pythonhosted.org/packages/1c/61/b545aaee28d81e410e91d75e236a53f342bbb49fd4538332afa1661ef0ae/google_cloud_vision-0.35.2-py2.py3-none-any.whl (226kB)
# Collecting google-api-core[grpc]<2.0.0dev,>=1.6.0 (from google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/8b/01/13758ff9b970008ccf9e0dcc3b86d0e01937d7485b9a2c6142c9c2bdb4da/google_api_core-1.7.0-py2.py3-none-any.whl (64kB)
# Requirement not upgraded as not directly required: pytz in c:\programdata\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2018.4)
# Requirement not upgraded as not directly required: requests<3.0.0dev,>=2.18.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2.18.4)
# Collecting googleapis-common-protos!=1.5.4,<2.0dev,>=1.5.3 (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/21/fd/0ea06fab3651857955f2240a20cf951a29c1cdfdc937c3d19d8575651a64/googleapis-common-protos-1.5.8.tar.gz
# Collecting protobuf>=3.4.0 (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/e8/df/d606d07cff0fc8d22abcc54006c0247002d11a7f2d218eb008d48e76851d/protobuf-3.6.1-cp36-cp36m-win_amd64.whl (1.1MB)
# Collecting google-auth<2.0dev,>=0.4.0 (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/4e/85/71b2dfbf5b4241cd031cc333ed71f90a271074a97cb2c517bb65f07a1a90/google_auth-1.6.2-py2.py3-none-any.whl (73kB)
# Requirement not upgraded as not directly required: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.11.0)
# Requirement not upgraded as not directly required: setuptools>=34.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (39.1.0)
# Collecting grpcio>=1.8.2; extra == "grpc" (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/bb/a7/fa027f411616f6e7c5899a8e3e1ab2e101808f8d62b6ee8b645411ed270b/grpcio-1.18.0-cp36-cp36m-win_amd64.whl (1.5MB)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2.6)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.22)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2018.4.16)
# Collecting rsa>=3.1.4 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Using cached https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Collecting cachetools>=2.0.0 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/39/2b/d87fc2369242bd743883232c463f28205902b8579cb68dcf5b11eee1652f/cachetools-3.1.0-py2.py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/da/98/8ddd9fa4d84065926832bcf2255a2b69f1d03330aa4d1c49cc7317ac888e/pyasn1_modules-0.2.4-py2.py3-none-any.whl (66kB)
# Collecting pyasn1>=0.1.3 (from rsa>=3.1.4->google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
# Building wheels for collected packages: googleapis-common-protos
#   Running setup.py bdist_wheel for googleapis-common-protos: started
#   Running setup.py bdist_wheel for googleapis-common-protos: finished with status 'done'
#   Stored in directory: C:\Users\Owner\AppData\Local\pip\Cache\wheels\51\ef\76\6ca53de13cc85eea40c641d75bb01355d97181ed64eb67bc8e
# Successfully built googleapis-common-protos
# Installing collected packages: protobuf, googleapis-common-protos, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, grpcio, google-api-core, google-cloud-vision
# Successfully installed cachetools-3.1.0 google-api-core-1.7.0 google-auth-1.6.2 google-cloud-vision-0.35.2 googleapis-common-protos-1.5.8 grpcio-1.18.0 protobuf-3.6.1 pyasn1-0.4.5 pyasn1-modules-0.2.4 rsa-4.0
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Install vision
# pip install --upgrade google-api-python-client
# pip install --upgrade google-cloud-vision

import io
import os
import pandas as pd

from google.cloud import vision
from google.cloud.vision import types

# https://cloud.google.com/vision/docs/libraries

# %%
ImageFolder = "C:/Users/Owner/Desktop/SMA/Assignment2/Natgeo/"
# Placeholders to store data
ImageID = []
MID = []
Description = []
Score = []


# Create empty data frame and vision API client
ImageLabels = pd.DataFrame()
client = vision.ImageAnnotatorClient()

ImageLabels = pd.DataFrame()
client = vision.ImageAnnotatorClient()

# empty dictionaries to store all image information
image_labels = {}
image_scores = {}

# Get labels and scores for every image in folder
for file in os.listdir(ImageFolder):
    filename = os.path.basename(file).split('.')[0] # Get image ID
    image_file = io.open(ImageFolder+file, 'rb') # Open image
    content = image_file.read() # Read image into memory
    image = types.Image(content=content) # Does something
    response = client.label_detection(image=image) # Gets response from API for image
    labels = response.label_annotations # Get labels from response
    Nlabels = len(labels) # Get the number of labels that were returned
    
    #create lists to store label and score in separate list
    l = []
    s = []
    for i in range(0, Nlabels): # For each label we will store the MID, label, and score
        l.append(labels[i].description)
        s.append(labels[i].score)
        image_labels[filename] = l #put label info from list into the dictionary
        image_scores[filename] = s #put score info from list into the dictionary

# create dataframe
df = pd.DataFrame()
df['imageid'] = image_labels.keys()
df['labels'] = image_labels.values()
df['scores'] = image_scores.values()

# %%
df
# Out:
#                   imageid                                             labels  \
# 0     1887675048681946284  [Reflection, Water, Blue, Waterway, Street, Sw...
# 1     1887750972126714187  [Sport venue, Product, Stadium, Fan, T-shirt, ...
# 2     1887939394339128382  [Eyewear, Glasses, Cool, Nail, Hand, Sunglasse...
# 3     1888007540646834631  [Hair, Face, Hairstyle, Forehead, Head, Eyebro...
# 4     1888083309374639933  [Transport, Green, Mode of transport, Public t...
# 5     1888083315372477617  [Eyewear, Glasses, Face, Head, Forehead, White...
# 6     1888083317788415675  [Transport, Standing, Train station, Train, Mo...
# 7     1888083319290047425  [Human leg, Leg, Footwear, Shoe, Thigh, Sittin...
# 8     1888083320824960560  [Sitting, Gentleman, Snapshot, Human, White-co...
# 9     1888158516456404761  [People, Adaptation, Water, Child, Soil, Fun, ...
# 10    1888279111470907589                              [Child, Horse, Smile]
# 11    1888354763528130949  [Building, Architecture, Facade, Sky, Hotel, H...
# 12    1888430312992553615  [Sky, Mountainous landforms, Mountain, Blue, M...
# 13    1888505922360208565  [Elephants and Mammoths, Vertebrate, Wildlife,...
# 14    1888585755989497878  [Red, Dress, Font, Stock photography, Fashion ...
# 15    1888585757516307856  [Head, Photography, Neck, Ear, Fashion accesso...
# 16    1888958815630742925  [Hat, Headgear, Fashion accessory, Cowboy hat,...
# 17    1889034010626180210  [Historic site, Holy places, Ancient history, ...
# 18    1889331592965215146  [Spring, Flower, Plant, Organism, Blossom, Pho...
# 19    1889331595557277728  [Natural landscape, Nature, Tree, Spring, Bran...
# 20    1889426907432537531  [Dog, Vertebrate, Canidae, Standard Poodle, Ma...
# 21    1889502167104968468  [Water transportation, Boat, Sky, Vehicle, Cal...
# 22    1889577852630891446  [Rock, Green, Formation, Geology, Bedrock, Out...
# 23    1889698482525118531  [Desert, Sand, Natural environment, Aeolian la...
# 24    1889773845227159161  [Face, Hair, Smile, Facial expression, Skin, E...
# 25    1889849386402332812  [Vertebrate, Mammal, Canidae, Fur, Dog breed, ...
# 26    1889925216827940189  [Blue, Water, Sky, Ocean, Sea, Aqua, Atmospher...
